# %% [markdown]
# # K-Means Clustering

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Data preparation

# %%
# Importing the dataset
df = pd.read_csv('bank.csv')
df = df.drop(['id'], axis=1)

# %%
df
# Out:
#      age     sex    income married  children  car mortgage delays
# 0     48  FEMALE  17546.00      NO         1   NO       NO    YES
# 1     40    MALE  30085.10     YES         3  YES      YES     NO
# 2     51  FEMALE  16575.40     YES         0  YES       NO    YES
# 3     23  FEMALE  20375.40     YES         3   NO       NO    YES
# 4     57  FEMALE  50576.30     YES         0   NO       NO     NO
# ..   ...     ...       ...     ...       ...  ...      ...    ...
# 595   61  FEMALE  47025.00      NO         2  YES      YES     NO
# 596   30  FEMALE   9672.25     YES         0  YES       NO    YES
# 597   31  FEMALE  15976.30     YES         0  YES       NO    YES
# 598   29    MALE  14711.80     YES         0   NO      YES    YES
# 599   38    MALE  26671.60      NO         0  YES      YES     NO
#
# [600 rows x 8 columns]

# %%
# Function Encoding
def encoding_char(x):
    char_var = list(set(x.columns) - set(x._get_numeric_data().columns))
    for col_names in char_var:
        f = pd.factorize(x[col_names])
        x[col_names] = pd.factorize(x[col_names])[0]
    return(x)

# %%
# Encoding categorical data
df = encoding_char(df)

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler().fit(df)
df_sc = sc.transform(df)
df_sc = pd.DataFrame(df_sc, columns = ['age','sex','income','married','children','car','mortgage','delays'])

# %% [markdown]
# ## Number of clusters

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 0)
    kmeans.fit(df_sc)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Using the silhouette method to find the optimal number of clusters
from sklearn.metrics import silhouette_score

sil = []

for k in range(2, 6):
  kmeans = KMeans(n_clusters = k).fit(df_sc)  
  preds = kmeans.fit_predict(df_sc)
  sil.append(silhouette_score(df_sc, preds, metric = 'euclidean'))


plt.plot(range(2, 6), sil)
plt.title('Silhouette Method')
plt.xlabel('Number of clusters')
plt.ylabel('Sil')
plt.show()

for i in range(len(sil)):
 print(str(i+2) +":"+ str(sil[i]))
# Out:
# 2:0.21240874808835405
# 3:0.185116340092845
# 4:0.21764624398181923
# 5:0.20068149763831755

# %% [markdown]
# ## Baseline model

# %%
# Fitting K-Means to the dataset
km = KMeans(n_clusters = 4, random_state = 0).fit(df_sc)
km4 = km.predict(df_sc)
pd.DataFrame(km.cluster_centers_, columns = ['age','sex','income','married','children','car','mortgage','delays']).round(2)
# Out:
#     age   sex  income  married  children   car  mortgage  delays
# 0  0.67  0.54    0.54     0.68      0.30  0.52      1.00     1.0
# 1  0.34  0.00    0.23     0.66      0.34  0.46      0.30    -0.0
# 2  0.28  1.00    0.22     0.63      0.30  0.44      0.37    -0.0
# 3  0.70  0.47    0.56     0.68      0.38  0.54      0.00     1.0

# %%
def plot_2d(X, label_list_cluster):
    plt.figure(figsize=(7, 7))
    plt.subplots_adjust(bottom=0.1)
    c = label_list_cluster
    plt.scatter(X[:, 0], X[:, 1], c=c, cmap='rainbow', label='True Position')
    plt.show()

# %%
plot_2d(df_sc[['age', 'income']].to_numpy(),km4)

# %% [markdown]
# ## Less features, less clusters

# %%
# Less features
X = ['age','income','delays']

# %%
# Fitting K-Means to the dataset
km_r = KMeans(n_clusters = 2, random_state = 0).fit(df_sc[X])
km2 = km_r.predict(df_sc[X])
km2_centers = pd.DataFrame(km_r.cluster_centers_, columns = ['age','income','delays']).round(2)
km2_centers
# Out:
#     age  income  delays
# 0  0.31    0.23    -0.0
# 1  0.69    0.55     1.0

# %%
def plot_2d_cores(X, label_list_cluster, cores):
    plt.figure(figsize=(7, 7))
    plt.subplots_adjust(bottom=0.1)
    c = label_list_cluster
    n = ('orange','green')
    plt.scatter(X[:, 0], X[:, 1], c=c, cmap='rainbow', label='True Position')
    plt.scatter(cores[:, 0], cores[:, 1], c=n, s = 500, marker = '*')
    plt.show()

# %%
plot_2d_cores(df_sc[['age', 'income']].to_numpy(),km2,km2_centers[['age', 'income']].to_numpy())

# %% [markdown]
# ## Results matching

# %%
# Importing hc clusters
import pickle
input = open('clust.pkl', 'rb')
obj = pickle.load(input)
input.close()
hc2 = obj['hc']

# %%
# Comparing Clustering Algorithms
from sklearn.metrics.cluster import adjusted_rand_score
adjusted_rand_score(hc2,km2)
# Out:
# 1.0

# %% [markdown]
# ## Pickle results

# %%
# Export km clusters
import pickle
obj = {'km': km2}
output = open('clust-km.pkl', 'wb')
pickle.dump(obj, output, 2)
output.close()
